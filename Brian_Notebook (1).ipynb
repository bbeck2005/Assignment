# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# ## My Jupyter Notebook on Watson Studio ##

# %% [markdown]
# **Brian Beck**
# Department of Defense Data Analyst

# %% [markdown]
# *I am interested in data science because i work with large amounts of data and I am interested in understanding better ways to organize and visualize the data.*

# %% [markdown]
# ### My code is to add numbers. ###

# %%
12+4
# Out:
# 16

# %% [markdown]
# Things to do on the weekend
# 1. running
# 2. housework
# 3. golf

# %% [markdown]
# ![OIP.jpg](attachment:ef75e27d-8d12-4c4c-927e-67fccb3864e7.jpg)

# %%
https://www.nhl.com/
